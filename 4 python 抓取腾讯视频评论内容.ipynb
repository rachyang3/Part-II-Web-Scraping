# %% [markdown]
# # python 抓取腾讯视频评论内容

# %%
import urllib.request
import re
import urllib.error

# %%
headers=("User_Agent","Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36 SE 2.X MetaSr 1.0")
#自定义opener
opener = urllib.request.build_opener()
opener.addheaders = [headers]
urllib.request.install_opener(opener)
cursor_id = '6394260346548095809'
v_id =1524402700840                   #这两个变量实现页数的变化
url = "https://video.coral.qq.com/varticle/2580302776/comment/v2?callback=_varticle2580302776commentv2&orinum=10&oriorder=o&pageflag=1&cursor="+cursor_id+"&scorecursor=0&orirepnum=2&reporder=o&reppageflag=1&source=9&_="+str(v_id)

# %%
for i in range(0,10):                         #每页爬取十条评论
    content = urllib.request.urlopen(url).read().decode("utf-8")       #使用正则表达式找到需要爬取的内容
    patnext = '"last":"(.*?)"'
    nextid = re.compile(patnext).findall(content)[0]
    patcomment = '"content":"(.*?)",'
    comment_content = re.compile(patcomment).findall(content)
    for j in range(1,len(comment_content)):
        print("-----第"+str(i)+str(j)+"条评论内容是：")
        #print(eval("u"+"\'"+comment_content[j]+"\'"))
        try:
            t1 = comment_content[j].encode('latin-1').decode('unicode_escape')
            print(t1)
        except Exception as e:
            print("***********该条评论含有有特殊字符************")
    url="https://video.coral.qq.com/varticle/2580302776/comment/v2?callback=_varticle2580302776commentv2&orinum=10&oriorder=o&pageflag=1&cursor="+nextid+"&scorecursor=0&orirepnum=2&reporder=o&reppageflag=1&source=9&_="+str(v_id+i)
# Out:
# -----第01条评论内容是：
# 反正我觉得演的非常好，喜剧色彩也很好，霸道水平也很好，腹黑水平也很好，互怼水平也不错，就是着急呀，每次眼看着要亲嘴的时候，就打扰了。真憋屈
# -----第02条评论内容是：
# 萧伯伯的小儿子满百岁？是满百日吧？这么明显的口误。
# -----第03条评论内容是：
# 李小冉适合演苦情戏，一脸的克夫相。看到都郁闷，实在不适合演爱情剧。
# -----第04条评论内容是：
# 故事情节太啰嗦太假了，看的让人不耐烦了
# -----第05条评论内容是：
# 苏云这个容整的令人看着就想吐…不是不喜欢而是越看越觉得脸太假
# -----第06条评论内容是：
# 于和伟演得好好，被圈粉了，不过他有时候的眼神，还有说话嗓音，和陈宝国特别像
# -----第07条评论内容是：
# 不会演着演着前妻全回来了吧！
# -----第08条评论内容是：
# 一但错过就永远错过了，杨柳已经错过了，希望盛夏不会错过
# -----第09条评论内容是：
# 为什么我一点也不喜欢盛夏，有没有人有同感，如果秋阳和杨柳在一起才是完美的
# -----第010条评论内容是：
# 真的是
# -----第011条评论内容是：
# 我们老家那边小孩一百天时也是说过百岁
# -----第012条评论内容是：
# 过百日就叫过百岁的
# -----第013条评论内容是：
# 什么克夫像？说话留点口德，吃不到葡萄说酸。
# -----第014条评论内容是：
# 这样针对演员也太不应该了！她演技挺好
# -----第015条评论内容是：
# 同感！
# -----第016条评论内容是：
# 丰唇了没？？老铁
# -----第017条评论内容是：
# 我现在很好奇他为什么离两次婚
# -----第018条评论内容是：
# 有可能！
# -----第019条评论内容是：
# 爱情的道路上最大的过错就是错过。
# -----第21条评论内容是：
# 于和伟的男人魅力爆发了，喜欢你！
# -----第22条评论内容是：
# 虐心插曲《我们怎么了》MV，喜欢这首歌！其中诸多扎心歌词让过往成为满满回忆杀，于和伟李小冉剧中的温馨追忆场面令人感动落泪。美好的爱情，遇见即是幸运，不要等到失去才懂得珍惜。
# -----第23条评论内容是：
# 就喜欢看你两玩暧昧哈哈哈
# -----第24条评论内容是：
# 为什么不就在一起试试呢？一起要个孩子，最不好的结果不也就是你俩都做好的离婚准备？矫情啊
# -----第25条评论内容是：
# 这杨柳是不是故意的。故意摔倒让秋阳留在她身边！
# -----第26条评论内容是：
# 苏云的嘴巴好丑。整失败了吧。大海好帅！！！！！
# -----第27条评论内容是：
# 我还是觉得秋阳和杨柳合适，毕竟杨柳为他付出了太多。盛夏和孟铮也很适合，生活中本身也有很多无耐！
# -----第28条评论内容是：
# 终于像了回男人，秋阳
# -----第29条评论内容是：
# 看了这么多集了。为什么我越看越累....感觉一直看不到头
# -----第210条评论内容是：
# 内分泌都这样了，婚都结了，还不敢有正常生理生活
# -----第211条评论内容是：
# 怕婚姻有牵绊麻烦
# -----第212条评论内容是：
# 我倒是觉得张丽和秋阳最合适。。。
# -----第213条评论内容是：
# 杨柳活该，早知如此何必当初！
# -----第214条评论内容是：
# 真正幸福的笑
# -----第215条评论内容是：
# 主演太费劲所以观众看的更累了呗！
# -----第31条评论内容是：
# 明明喜欢为什么不说出来，这么难为自己呢。
# -----第32条评论内容是：
# 这两人 一个说不结婚 其实也想换种生活方式 又怕被伤害
# 另一个千挑万选 说是给孩子找个爸 其实还是很在意另一半是什么样的人
# 一个人久了年龄越来越大 就越不想结婚 个人假毛病越多 都想太多～
# 都渴望被关心 又怕失败和被伤害！！！
# -----第33条评论内容是：
# 不清楚为什么别人一个电话秋阳就立马能赶到，偏偏盛夏需要他的时候永远赶不到，我也不喜欢自己的老公是这种类型的人，我觉得离开是最好的，秋阳这种是性格，是改变不了的
# -----第34条评论内容是：
# 庞大海怎么这样，背后说别人坏话！！！！！
# -----第35条评论内容是：
# 有觉得庞大海长的像胡歌的吗，瘦点更像
# -----第36条评论内容是：
# 绝对不看预告！坐等更新！
# -----第37条评论内容是：
# 杨柳不让秋阳回头这动作有点恶心哦
# -----第38条评论内容是：
# 这么狗血的剧情，还有这么多人还想看续集，搞不懂，我老婆喜欢看，我陪她看了两集就实在看不下去了
# -----第39条评论内容是：
# 每次看到苏云的嘴唇就觉得说不出的感觉，这样的闺蜜真的不要也罢
# -----第310条评论内容是：
# 只能选择离开
# -----第311条评论内容是：
# 庞大海好像是克拉恋人的林子良
# -----第312条评论内容是：
# 有一一点
# -----第313条评论内容是：
# 我刚看完上一集这一集就正正好好更新了
# -----第314条评论内容是：
# 你懂个P
# -----第315条评论内容是：
# 看电视大家都有评论的权利，你看不惯可以不说，就你人缘好，如果朋友把你的事情到处说，就你喜欢，就你朋友多，毛病
# -----第316条评论内容是：
# 想你这种人，不配拥有最真挚的友情
# -----第41条评论内容是：
# 我笑了 哈哈哈哈哈哈 。逗死了
# -----第42条评论内容是：
# 看了这片子以后觉得其实男人不需要那么帅，只要心疼人就可以
# -----第43条评论内容是：
# 讨厌杨柳一家子‘包括那个老东西
# -----第44条评论内容是：
# 这种洁癖挺假的，那么在意，去卫生间出来手还不是要摸门？我也有小洁癖，也不至于这样
# -----第45条评论内容是：
# 快去追她。她一定会留下的。
# -----第46条评论内容是：
# 秋阳把盛夏追回来！！！！
# -----第47条评论内容是：
# 贱男人一个！有这么好的生活！这么好的老婆！衣食无忧！还有外遇！日子过得太好了！就做贱！都不知道现在有很多人天天辛苦赚钱养家的！
# -----第48条评论内容是：
# 估计又要上演两个人和好了跟女主离婚，最后杨柳还是成全了男女主自动退出
# -----第49条评论内容是：
# 这个苏云一直撮合盛夏跟谁谁在一起，还不是为了自己能跟秋阳在一起，作逼这种人
# -----第410条评论内容是：
# 李小冉除了皮肤特别白长得还真是一般，并且嘴长得特丑
# -----第411条评论内容是：
# 估计是她年纪大了，眼神也死气沉沉的，变了好多
# -----第412条评论内容是：
# 我也有一点点洁癖，这个太夸张
# -----第413条评论内容是：
# 同感
# -----第61条评论内容是：
# 苏云不是怀孕了吗！怎么不提了
# -----第62条评论内容是：
# 张成龙到底是想干嘛？不想离婚还总找女人聊天？还见面，还被骗！太蠢了！
# -----第63条评论内容是：
# 看到这才明白这个电视的名字。别离真的不能离啊！爱是慢慢积累出来的。他们的互相包容，互相理解，认真听对方的条件，并能遵守。真的很不容易，这样互相产生爱，很自然。真爱，绝不能离。结局一定很好。期待！
# -----第64条评论内容是：
# 女的坐车没扣安全带，罚款200人民币
# -----第65条评论内容是：
# 这个杨柳应该找个没人的地方死掉最好，大家耳根都清净了。这女人活在世上只能害人。
# -----第66条评论内容是：
# 这苏云就爱占便宜，最坑的闺蜜
# -----第67条评论内容是：
# 千万不能喜欢上有过家室的人。太累，越是彼此相爱越是伤的深。人在感情上本来就没有那么大度。就不要去触碰那些危险的东西！
# -----第68条评论内容是：
# 没有人发现男主跟女主发微信讲第二声她醒了激动了一点吗！他的潜台词是我们可以在一起了！
# -----第69条评论内容是：
# 纯属我个人的意见我不同情杨柳的，因为她在爱情面前是自私的。如果杨柳真的爱秋阳为什么不告诉秋阳呢？我想秋阳那么爱她会照顾她的。我想这部电视剧唯一的亮点就是秋阳和盛夏从没有吵过。处事冷静……现在就不怕拖累秋阳吗？
# -----第610条评论内容是：
# 人家是假性怀孕
# -----第611条评论内容是：
# 感觉杨柳出场时气场很大，后来她越来越没什么看头，还没很自私，只会给秋阳制造麻烦
# -----第612条评论内容是：
# 盛夏真的伟大，为秋阳做了很多
# -----第613条评论内容是：
# ？不二二
# -----第614条评论内容是：
# 的
